# %% [markdown]
# <a href="https://colab.research.google.com/github/lockiultra/greenatom/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xf ./drive/MyDrive/greenatom/aclImdb_v1.tar.gz

# %%
import os
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.DataFrame(columns=['text', 'rating', 'status'])
df_test = pd.DataFrame(columns=['text', 'rating', 'status'])

# %%
os.chdir('/content/aclImdb/train')
for status in ['neg', 'pos']:
  for curr_file in os.listdir(f'./{status}'):
    with open(f'./{status}/{curr_file}', 'r') as f:
      text = f.read()
      rating = curr_file.split('.')[0].split('_')[1]
    df_train = df_train.append({'text': text, 'rating': rating, 'status': status}, ignore_index=True)

# %%
df_train
# Out:
#                                                     text rating status
# 0      I jotted down a few notes here on THE FIRST PO...      4    neg
# 1      If you look at Corey Large's information here ...      3    neg
# 2      the Germans all stand out in the open and get ...      2    neg
# 3      **SPOILERS**This was an ugly movie, and I'm so...      3    neg
# 4      Awful. This thriller should have buried. What ...      1    neg
# ...                                                  ...    ...    ...
# 25801  Wonderful film that mixes documentary and fict...      9    pos
# 25802  I missed almost all of the first season, but w...     10    pos
# 25803  I'd love to give this movie a 10/10, but in it...      8    pos
# 25804  This is a rip-roaring British comedy movie and...     10    pos
# 25805  Liked Stanley & Iris very much. Acting was ver...      9    pos
#
# [25806 rows x 3 columns]

# %%
os.chdir('/content/aclImdb/test')
for status in ['neg', 'pos']:
  for curr_file in os.listdir(f'./{status}'):
    with open(f'./{status}/{curr_file}', 'r') as f:
      text = f.read()
      rating = curr_file.split('.')[0].split('_')[1]
    df_test = df_test.append({'text': text, 'rating': rating, 'status': status}, ignore_index=True)

# %%
df_test
# Out:
#                                                     text rating status
# 0      Julie Andrews satirically prods her own goody-...      3    neg
# 1      Unfortunately House of D is just awful, with a...      1    neg
# 2      I had the unlucky experience of stumbling upon...      2    neg
# 3      **May Contain Spoilers**<br /><br />A luckless...      3    neg
# 4      This movie is retarded a cheap movie that trie...      1    neg
# ...                                                  ...    ...    ...
# 24995  WALLACE & GROMIT: THE CURSE OF THE WERE-RABBIT...     10    pos
# 24996  Good movie, great story, great characters, I e...      8    pos
# 24997  I would love for members of the cast and crew ...     10    pos
# 24998  Hearkening back to those "Good Old Days" of 19...     10    pos
# 24999  I was pleasantly surprised to find this movie ...      9    pos
#
# [25000 rows x 3 columns]

# %%
df_train['status'] = df_train['status'].replace({'neg': 0, 'pos': 1})
df_test['status'] = df_test['status'].replace({'neg': 0, 'pos': 1})

# %%
df_train.to_csv('/content/drive/MyDrive/greenatom/train.csv')
df_test.to_csv('/content/drive/MyDrive/greenatom/test.csv')
